# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd '/content/drive/Shareddrives/NLP Project'
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/NLP Project

# %%
# Run NER predictions and save annotations

# Done - no need to update

# %%
# Produce new test input files for task 2 Event model

# Done - no need to update

# %%
# Run Event predictions and save annotations

# Done - no need to update

# %%
# Produce new test input files for task 3 Context models

 # Done

# %%
# Run Context predictions and save annotations

# Done

# %%
# Run final eval script
# %cd '/content/drive/Shareddrives/NLP Project/notebooks/utils/'
import eval_script
# %cd '/content/drive/Shareddrives/NLP Project'
# Out:
# /content/drive/Shareddrives/NLP Project/notebooks/utils
# /content/drive/Shareddrives/NLP Project

# %%
# Evaluate using script
gold_standard = 'data/split_data/test/' 
predicted = 'data/split_data/context_predicted_annotations/'
evaluator_tag_s, evaluator_tag_l = eval_script.main(gold_standard, predicted, False)
# Out:
# Files skipped in data/split_data/test/:
# 100-02.ann, 158-02.ann
#
# ******************** Evaluation n2c2 2022 Track 1 ********************
# ************* Contextualized Medication Event Extraction *************
#
# *********************** Medication Extraction ************************
#                       ------- strict -------    ------ lenient -------
#                       Prec.   Rec.    F(b=1)    Prec.   Rec.    F(b=1)
#                 Drug  0.9519  0.9439  0.9479    0.9760  0.9677  0.9718
#
#
# ************************ Event Classification ************************
#                       ------- strict -------    ------ lenient -------
#                       Prec.   Rec.    F(b=1)    Prec.   Rec.    F(b=1)
#          Disposition  0.7843  0.8333  0.8081    0.7974  0.8472  0.8215
#        Nodisposition  0.8871  0.8836  0.8854    0.9149  0.9112  0.9130
#         Undetermined  0.6327  0.5000  0.5586    0.6327  0.5000  0.5586
# ...

# %%
evaluator_tag_s.scores['attributes']
# Out:
# {'fn': 90,
#  'fp': 88,
#  'micro': {'f1': 0.42207792207792205,
#   'precision': 0.42483660130718953,
#   'recall': 0.41935483870967744},
#  'tn': 0,
#  'tp': 65}

# %%
vars(evaluator_tag_s)
# Out:
# {'attributes': ('Action',
#   'Temporality',
#   'Certainty',
#   'Actor',
#   'Negation',
#   'Combined'),
#  'scores': {'attributes': {'fn': 90,
#    'fp': 88,
#    'micro': {'f1': 0.42207792207792205,
#     'precision': 0.42483660130718953,
#     'recall': 0.41935483870967744},
#    'tn': 0,
#    'tp': 65},
#   'tags': {'fn': 0,
#    'fp': 0,
#    'micro': {'f1': 0.0, 'precision': 0.0, 'recall': 0.0},
#    'tn': 0,
#    'tp': 0}},
#  'tags': ('Drug', 'Disposition', 'NoDisposition', 'Undetermined')}
