# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd '/content/drive/Shareddrives/NLP Project'
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/NLP Project

# %% [markdown]
# ### Part 1: import required libraries

# %%
# !pip install accelerate
# !pip install seqeval
# !pip install datasets 
# !pip install torch
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#      |████████████████████████████████| 58 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=e9cfb639902efa3279d23209dcc8e8976d1b8ebaa244b5cbea2c6c6304dfbc3c
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# ...
#      |████████████████████████████████| 312 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 212 kB 65.3 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 134 kB 74.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 64.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 271 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 144 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.7 MB/s
# ...
#   Attempting uninstall: urllib3
# ...

# %%
# you only need to install the packages if you have not already. On Google Colab you need to reinstall these every time.
# !pip install pytorch-lightning=="1.5.8"
# Out:
# ...
#      |████████████████████████████████| 526 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 397 kB 52.4 MB/s
# ...
#      |████████████████████████████████| 829 kB 35.0 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=824a1e625327406fe82479c67a660c9f5f1297f9474c6350c8548eda18670f68
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ...

# %%
# %cd 'notebooks/subtask 3 Context'
import importlib
import sequence_classifier
# Out:
# /content/drive/Shareddrives/NLP Project/notebooks/subtask 3 Context

# %%
import os
os.chdir('/content/drive/Shareddrives/NLP Project')

DATA_DIR = "data/split_data/context_input"
sequence_classifier.classify(DATA_DIR,"negation")
# Out:
# 03/12/2022 19:03:33 - INFO - pytorch_lightning.utilities.seed -   Global seed set to 42
# 03/12/2022 19:03:33 - INFO - sequence_classifier -   Initilazing BaseModel
# /content/drive/Shareddrives/NLP Project/notebooks/subtask 3 Context
# Namespace(data_dir='data/split_data/context_input', do_predict=True, do_train=True, eval_batch_size=16, gpus=1, learning_rate=5e-05, max_epochs=5, model_name='emilyalsentzer/Bio_ClinicalBERT', num_workers=16, optimizer='adamw', output_dir='data/models/negation', seed=42, task='negation', task_bert='negation', train_batch_size=16)
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# ...

# %%
import json
import torch
import pytorch_lightning as pl
from torch.utils.data import DataLoader
from sequence_classifier import BERT_PL
ckpt_path = 'data/models/negation/version_11-03-2022--04-27-19/checkpoints'
best_model_path = os.path.join(ckpt_path, "best_model.ckpt")
model = BERT_PL.load_from_checkpoint(best_model_path).cuda()

trainer = pl.Trainer(gpus=1)

# %%
datapath = 'data/trainingdata_v3/dev_negation.json'
with open(datapath) as json_file:
    data = [json.loads(line) for line in json_file]
parsed_data =[]
for line in data:
    parsed_data.append([sequence_classifier.LABEL_TO_INT["negation"][line["label"]], line["text"]])

dataset = sequence_classifier.BERTSST2Dataset(model.tokenizer, parsed_data)
test_data = DataLoader(dataset, batch_size=8, collate_fn=dataset.collate_fn)
prediction_list = []
for i, batch in enumerate(test_data):
    torch.cuda.empty_cache()
    b1, b2, b3 = (batch[0].cuda(), batch[2].cuda(), 
                  batch[1].cuda())
    ughhh = {"input_ids": b1, "labels": b2, "attention_mask": b3}
    output = model(**ughhh)
    del b1
    del b2
    del b3
    del ughhh
    prediction_list.append(output[1].tolist())
    del output
    torch.cuda.empty_cache()

# %%
prediction_list
