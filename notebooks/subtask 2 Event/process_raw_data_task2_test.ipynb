# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/Shareddrives/NLP Project/notebooks/utils/'
from create_model_inputs_task2 import process_n2c2_files_task2
# %cd '/content/drive/Shareddrives/NLP Project/'
# Out:
# /content/drive/Shareddrives/NLP Project/notebooks/utils
# /content/drive/Shareddrives/NLP Project

# %%
base_dir = 'data/split_data'
test_ann_dir = 'ner_predicted_annotations'
data_split = 'test'

# Produce one set of files that include the test files, but are created from gold standard
# Produce another file with only the mentions from the NER task
from_ner_list = [True, False]

for from_ner in from_ner_list:
    process_n2c2_files_task2(base_dir, data_split, from_ner, test_ann_dir)
# Out:
# {'NoDisposition': 507, 'Disposition': 155, 'Undetermined': 62}
# 724
